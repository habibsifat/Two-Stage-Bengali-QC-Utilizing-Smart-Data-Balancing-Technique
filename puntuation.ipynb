# %%
import fileinput
from google.colab import files
uploaded = files.upload()

# %%
s = open("qa-corpus.txt").read()
s = s.replace('।', ' । ')
f = open("x.txt", 'w')
f.write(s)
f.close()

# %%
s = open("x.txt").read()
s = s.replace('?', ' ? ')
f = open("y.txt", 'w')
f.write(s)
f.close()

# %%
s = open("y.txt").read()
s = s.replace(',', ' , ')
f = open("3.txt", 'w')
f.write(s)
f.close()

# %%
s = open("3.txt").read()
s = s.replace('.', ' . ')
f = open("4.txt", 'w')
f.write(s)
f.close()

# %%
s = open("4.txt").read()
s = s.replace('‘', ' ‘ ')
f = open("5.txt", 'w')
f.write(s)
f.close()

# %%
s = open("5.txt").read()
s = s.replace('’', ' ’ ')
f = open("6.txt", 'w')
f.write(s)
f.close()

# %%
s = open("6.txt").read()
s = s.replace('-', ' - ')
f = open("7.txt", 'w')
f.write(s)
f.close()

# %%
s = open("7.txt").read()
s = s.replace('#', ' # ')
f = open("8.txt", 'w')
f.write(s)
f.close()

# %%
s = open("8.txt").read()
s = s.replace('*', ' * ')
f = open("a.txt", 'w')
f.write(s)
f.close()

# %%
s = open("a.txt").read()
s = s.replace('/', ' / ')
f = open("b.txt", 'w')
f.write(s)
f.close()

# %%
s = open("b.txt").read()
s = s.replace(':', ' : ')
f = open("c.txt", 'w')
f.write(s)
f.close()

# %%
s = open("c.txt").read()
s = s.replace('"', ' " ')
f = open("d.txt", 'w')
f.write(s)
f.close()

# %%
s = open("d.txt").read()
s = s.replace(';', ' ; ')
f = open("e.txt", 'w')
f.write(s)
f.close()

# %%
s = open("e.txt").read()
s = s.replace('!', ' ! ')
f = open("f.txt", 'w')
f.write(s)
f.close()

# %%
s = open("f.txt").read()
s = s.replace('||', ' || ')
f = open("g.txt", 'w')
f.write(s)
f.close()

# %%
s = open("g.txt").read()
s = s.replace('(', ' ( ')
f = open("h.txt", 'w')
f.write(s)
f.close()

# %%
s = open("h.txt").read()
s = s.replace(')', ' ) ')
f = open("i.txt", 'w')
f.write(s)
f.close()

# %%
s = open("i.txt").read()
s = s.replace('[', ' [ ')
f = open("j.txt", 'w')
f.write(s)
f.close()

# %%
s = open("j.txt").read()
s = s.replace(']', ' ] ')
f = open("k.txt", 'w')
f.write(s)
f.close()

# %%
s = open("k.txt").read()
s = s.replace('{', ' { ')
f = open("l.txt", 'w')
f.write(s)
f.close()

# %%
s = open("l.txt").read()
s = s.replace('}', ' } ')
f = open("2017_2-final.txt", 'w')
f.write(s)
f.close()

# %%
s = open("2017_2-final.txt").read()
len(s)
# Out:
# 233924
